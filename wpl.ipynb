# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r'C:\Users\harsh\OneDrive\Desktop\My Projects\WPL\Day1\deliveries.csv')
df2 = pd.read_csv(r'C:\Users\harsh\OneDrive\Desktop\My Projects\WPL\Day1\matches.csv')

# %%
dev = df1.loc[(df1['batting_team'] == 'Mumbai Indians')& (df1['bowling_team'].isin(['Delhi Daredevils','Delhi Capitals']))]
dev.head()
# Out:
#       match_id  inning    batting_team      bowling_team  over  ball  \
# 5512        24       1  Mumbai Indians  Delhi Daredevils     1     1
# 5513        24       1  Mumbai Indians  Delhi Daredevils     1     2
# 5514        24       1  Mumbai Indians  Delhi Daredevils     1     3
# 5515        24       1  Mumbai Indians  Delhi Daredevils     1     4
# 5516        24       1  Mumbai Indians  Delhi Daredevils     1     5
#
#          batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 5512    PA Patel  JC Buttler  K Rabada              0  ...         0
# 5513  JC Buttler    PA Patel  K Rabada              0  ...         0
# 5514  JC Buttler    PA Patel  K Rabada              0  ...         0
# 5515    PA Patel  JC Buttler  K Rabada              0  ...         0
# 5516  JC Buttler    PA Patel  K Rabada              0  ...         0
#
#       legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
match = df2.loc[df2['team2'].isin(['Delhi Daredevils', 'Delhi Capitals']) & (df2['team1'] == 'Mumbai Indians')]

match.head()
# Out:
#       id  season         city        date           team1             team2  \
# 23    24    2017       Mumbai  2017-04-22  Mumbai Indians  Delhi Daredevils
# 43    44    2017        Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
# 81    82    2008       Mumbai  2008-05-04  Mumbai Indians  Delhi Daredevils
# 108  109    2008        Delhi  2008-05-24  Mumbai Indians  Delhi Daredevils
# 149  150    2009  East London  2009-05-08  Mumbai Indians  Delhi Daredevils
#
#           toss_winner toss_decision  result  dl_applied            winner  \
# 23   Delhi Daredevils         field  normal           0    Mumbai Indians
# 43   Delhi Daredevils         field  normal           0    Mumbai Indians
# 81   Delhi Daredevils         field  normal           0    Mumbai Indians
# 108  Delhi Daredevils         field  normal           0  Delhi Daredevils
# 149    Mumbai Indians           bat  normal           0  Delhi Daredevils
#
# ...

# %%
result = match.groupby(by ='winner')['winner']
result.count()
# Out:
# winner
# Delhi Daredevils     7
# Mumbai Indians      10
# Name: winner, dtype: int64

# %%
result = match.groupby(by ='toss_winner')['toss_decision']
result.describe()
# Out:
#                  count unique    top freq
# toss_winner
# Delhi Daredevils    11      1  field   11
# Mumbai Indians       6      1    bat    6

# %%
result = match.groupby(by ='toss_winner')['winner','toss_decision']
result.describe()
# Out:
# C:\Users\harsh\AppData\Local\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                  winner                             toss_decision         \
#                   count unique             top freq         count unique
# toss_winner
# Delhi Daredevils     11      2  Mumbai Indians    7            11      1
# Mumbai Indians        6      2  Mumbai Indians    3             6      1
#
#
#                     top freq
# toss_winner
# Delhi Daredevils  field   11
# Mumbai Indians      bat    6

# %% [markdown]
# ## If Delhi won the toss there is 50:50 chance for both the teams to win Delhi will decide to bat first
# ## If MI won the toss there is 70% chance that Mumbai will MI will decide to field first
# # There is High Probability MI will Win the Match

# %%
mum_win = match.loc[match['toss_winner'] == 'Mumbai Indians']
mum_win[['date','toss_winner', 'toss_decision','winner','win_by_runs','win_by_wickets']]
# Out:
#            date     toss_winner toss_decision            winner  win_by_runs  \
# 149  2009-05-08  Mumbai Indians           bat  Delhi Daredevils            0
# 220  2010-04-13  Mumbai Indians           bat    Mumbai Indians           39
# 389  2013-04-09  Mumbai Indians           bat    Mumbai Indians           44
# 407  2013-04-21  Mumbai Indians           bat  Delhi Daredevils            0
# 472  2014-04-27  Mumbai Indians           bat  Delhi Daredevils            0
# 729    18/04/19  Mumbai Indians           bat    Mumbai Indians           40
#
#      win_by_wickets
# 149               7
# 220               0
# 389               0
# 407               9
# 472               6
# 729               0

# %% [markdown]
# ## Mumbai won the toss , it will decide bat

# %%
delhi_win = match.loc[match['toss_winner'].isin(['Delhi Daredevils','Delhi Capitals'])]
delhi_win[['date','toss_winner', 'toss_decision','winner','win_by_runs','win_by_wickets']]
# Out:
#            date       toss_winner toss_decision            winner  \
# 23   2017-04-22  Delhi Daredevils         field    Mumbai Indians
# 43   2017-05-06  Delhi Daredevils         field    Mumbai Indians
# 81   2008-05-04  Delhi Daredevils         field    Mumbai Indians
# 108  2008-05-24  Delhi Daredevils         field  Delhi Daredevils
# 169  2009-05-21  Delhi Daredevils         field  Delhi Daredevils
# 182  2010-03-17  Delhi Daredevils         field    Mumbai Indians
# 281  2011-05-07  Delhi Daredevils         field    Mumbai Indians
# 326  2012-04-16  Delhi Daredevils         field  Delhi Daredevils
# 507  2014-05-23  Delhi Daredevils         field    Mumbai Indians
# 622  2016-05-15  Delhi Daredevils         field    Mumbai Indians
# 644    14/04/18  Delhi Daredevils         field  Delhi Daredevils
#
#      win_by_runs  win_by_wickets
# 23            14               0
# 43           146               0
# 81            29               0
# 108            0               5
# ...

# %% [markdown]
# ## if delhi won the toss it will choose field

# %%
rohit_review = dev.loc[dev['batsman'] == 'RG Sharma']
rohit_review['player_dismissed'].fillna(value = 0, inplace = True)
rohit_score = rohit_review.groupby('match_id')['batsman_runs']
rohit_score.sum().mean()
# Out:
# 31.27777777777778

# %% [markdown]
# # Avg Rohit Score is 31 against Delhi

# %%
rabada_review = df1.loc[df1['bowler'] == 'K Rabada']
rabada_review['player_dismissed'].fillna(value = 0, inplace = True)
rab = rabada_review[rabada_review['player_dismissed'] != 0].groupby('match_id')['player_dismissed']
rab.describe()
# Out:
# C:\Users\harsh\AppData\Local\Anaconda\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#          count unique                top freq
# match_id
# 24           2      2           PA Patel    1
# 31           2      2          SP Narine    1
# 41           3      3           AJ Finch    1
# 44           1      1          RG Sharma    1
# 11139        2      2        BCJ Cutting    1
# 11141        1      1          KM Jadhav    1
# 11146        2      2          PP Chawla    1
# 11149        3      3     Mohammed Shami    1
# 11152        1      1          DA Warner    1
# 11311        4      4             P Negi    1
# 11317        2      2         RV Uthappa    1
# 11321        4      4            K Ahmed    1
# ...

# %%
rabada_review[rabada_review['player_dismissed'] !=0].groupby('match_id')['player_dismissed'].describe().median()
# Out:
# count     2.0
# unique    2.0
# freq      1.0
# dtype: float64

# %% [markdown]
# ## On an average Rabada takes only 2 wicket

# %%
df1[df1['bowling_team'] == 'Mumbai Indians'].groupby('match_id')['wide_runs'].sum().median()
# Out:
# 4.0

# %%
df1[df1['bowling_team'].isin(['Delhi Daredevils','Delhi Capitals'])].groupby('match_id')['wide_runs'].sum().median()
# Out:
# 4.0

# %% [markdown]
# ## On an average both teams give 4 extra runs in one innings
